# %%
import pandas as pd

# %%
df=pd.read_csv("presidents.csv")
df.head()
# Out:
#    Presidency          President   \
# 0            1  George Washington
# 1            2         John Adams
# 2            3   Thomas Jefferson
# 3            4      James Madison
# 4            5       James Monroe
#
#                                   Wikipedia Entry Took office  Left office   \
# 0  http://en.wikipedia.org/wiki/George_Washington   30/04/1789    4/03/1797
# 1         http://en.wikipedia.org/wiki/John_Adams    4/03/1797    4/03/1801
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson    4/03/1801    4/03/1809
# 3      http://en.wikipedia.org/wiki/James_Madison    4/03/1809    4/03/1817
# 4       http://en.wikipedia.org/wiki/James_Monroe    4/03/1817    4/03/1825
#
#                    Party               Portrait                  Thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 1             Federalist          JohnAdams.jpg         thmb_JohnAdams.jpg
# ...

# %%
df=df.rename(mapper=str.lower,axis="columns")
df=df.rename(mapper=str.strip,axis="columns")
df
# Out:
#     presidency                    president  \
# 0            1            George Washington
# 1            2                   John Adams
# 2            3             Thomas Jefferson
# 3            4                James Madison
# 4            5                 James Monroe
# 5            6            John Quincy Adams
# 6            7               Andrew Jackson
# 7            8             Martin Van Buren
# 8            9       William Henry Harrison
# 9           10                   John Tyler
# 10          11                James K. Polk
# 11          12               Zachary Taylor
# 12          13             Millard Fillmore
# 13          14              Franklin Pierce
# 14          15               James Buchanan
# 15          16              Abraham Lincoln
# 16          17               Andrew Johnson
# 17          18             Ulysses S. Grant
# 18          19          Rutherford B. Hayes
# 19          20            James A. Garfield
# ...

# %%
def splitname(row):
#     the row is a single series object whihc is single row indexed by column name
    row['first']=row['president'].split(" ")[0]
    row['last']=row['president'].split(" ")[-1]
    return row

df=df.apply(splitname,axis='columns')
df.head()
# Out:
#    presidency          president  \
# 0           1  George Washington
# 1           2         John Adams
# 2           3   Thomas Jefferson
# 3           4      James Madison
# 4           5       James Monroe
#
#                                   wikipedia entry took office left office  \
# 0  http://en.wikipedia.org/wiki/George_Washington  30/04/1789   4/03/1797
# 1         http://en.wikipedia.org/wiki/John_Adams   4/03/1797   4/03/1801
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson   4/03/1801   4/03/1809
# 3      http://en.wikipedia.org/wiki/James_Madison   4/03/1809   4/03/1817
# 4       http://en.wikipedia.org/wiki/James_Monroe   4/03/1817   4/03/1825
#
#                     party              portrait                  thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 1             Federalist          JohnAdams.jpg         thmb_JohnAdams.jpg
# 2  Democratic-Republican    Thomasjefferson.gif   thmb_Thomasjefferson.gif
# ...

# %%
df
# Out:
#     presidency                    president  \
# 0            1            George Washington
# 1            2                   John Adams
# 2            3             Thomas Jefferson
# 3            4                James Madison
# 4            5                 James Monroe
# 5            6            John Quincy Adams
# 6            7               Andrew Jackson
# 7            8             Martin Van Buren
# 8            9       William Henry Harrison
# 9           10                   John Tyler
# 10          11                James K. Polk
# 11          12               Zachary Taylor
# 12          13             Millard Fillmore
# 13          14              Franklin Pierce
# 14          15               James Buchanan
# 15          16              Abraham Lincoln
# 16          17               Andrew Johnson
# 17          18             Ulysses S. Grant
# 18          19          Rutherford B. Hayes
# 19          20            James A. Garfield
# ...

# %%
# above method is the general method fo doing this

# %%
del(df['first'])
del(df['last'])
df
# Out:
#     presidency                    president  \
# 0            1            George Washington
# 1            2                   John Adams
# 2            3             Thomas Jefferson
# 3            4                James Madison
# 4            5                 James Monroe
# 5            6            John Quincy Adams
# 6            7               Andrew Jackson
# 7            8             Martin Van Buren
# 8            9       William Henry Harrison
# 9           10                   John Tyler
# 10          11                James K. Polk
# 11          12               Zachary Taylor
# 12          13             Millard Fillmore
# 13          14              Franklin Pierce
# 14          15               James Buchanan
# 15          16              Abraham Lincoln
# 16          17               Andrew Johnson
# 17          18             Ulysses S. Grant
# 18          19          Rutherford B. Hayes
# 19          20            James A. Garfield
# ...

# %%
import pandas as pd

sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj1 = pd.Series(sdata)
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj2 = pd.Series(sdata, index=states)
obj3 = pd.isnull(obj2)

# %%
obj1
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
obj2
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
obj3
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
x=obj2['California']
obj3['California']
# Out:
# True

# %%
import pandas as pd
d = {
    '1': 'Alice',
    '2': 'Bob',
    '3': 'Rita',
    '4': 'Molly',
    '5': 'Ryan'
}
s= pd.Series(d)

# %%
s
# Out:
# 1    Alice
# 2      Bob
# 3     Rita
# 4    Molly
# 5     Ryan
# dtype: object

# %%
s.iloc[0:2]
# Out:
# 1    Alice
# 2      Bob
# dtype: object

# %%
df=pd.read_csv("presidents.csv")
df.head()
# Out:
#    Presidency          President   \
# 0            1  George Washington
# 1            2         John Adams
# 2            3   Thomas Jefferson
# 3            4      James Madison
# 4            5       James Monroe
#
#                                   Wikipedia Entry Took office  Left office   \
# 0  http://en.wikipedia.org/wiki/George_Washington   30/04/1789    4/03/1797
# 1         http://en.wikipedia.org/wiki/John_Adams    4/03/1797    4/03/1801
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson    4/03/1801    4/03/1809
# 3      http://en.wikipedia.org/wiki/James_Madison    4/03/1809    4/03/1817
# 4       http://en.wikipedia.org/wiki/James_Monroe    4/03/1817    4/03/1825
#
#                    Party               Portrait                  Thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 1             Federalist          JohnAdams.jpg         thmb_JohnAdams.jpg
# ...

# %%
df=pd.read_csv("presidents.csv")
df.head()
# Out:
#    Presidency          President   \
# 0            1  George Washington
# 1            2         John Adams
# 2            3   Thomas Jefferson
# 3            4      James Madison
# 4            5       James Monroe
#
#                                   Wikipedia Entry Took office  Left office   \
# 0  http://en.wikipedia.org/wiki/George_Washington   30/04/1789    4/03/1797
# 1         http://en.wikipedia.org/wiki/John_Adams    4/03/1797    4/03/1801
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson    4/03/1801    4/03/1809
# 3      http://en.wikipedia.org/wiki/James_Madison    4/03/1809    4/03/1817
# 4       http://en.wikipedia.org/wiki/James_Monroe    4/03/1817    4/03/1825
#
#                    Party               Portrait                  Thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 1             Federalist          JohnAdams.jpg         thmb_JohnAdams.jpg
# ...

# %%
df.rename(mapper=str.lower,axis="columns")
# Out:
#     presidency                    president   \
# 0             1            George Washington
# 1             2                   John Adams
# 2             3             Thomas Jefferson
# 3             4                James Madison
# 4             5                 James Monroe
# 5             6            John Quincy Adams
# 6             7               Andrew Jackson
# 7             8             Martin Van Buren
# 8             9       William Henry Harrison
# 9            10                   John Tyler
# 10           11                James K. Polk
# 11           12               Zachary Taylor
# 12           13             Millard Fillmore
# 13           14              Franklin Pierce
# 14           15               James Buchanan
# 15           16              Abraham Lincoln
# 16           17               Andrew Johnson
# 17           18             Ulysses S. Grant
# 18           19          Rutherford B. Hayes
# 19           20            James A. Garfield
# ...

# %%
df.rename(mapper=lambda x:x.upper(),axis="columns")
# Out:
#     PRESIDENCY                    PRESIDENT   \
# 0             1            George Washington
# 1             2                   John Adams
# 2             3             Thomas Jefferson
# 3             4                James Madison
# 4             5                 James Monroe
# 5             6            John Quincy Adams
# 6             7               Andrew Jackson
# 7             8             Martin Van Buren
# 8             9       William Henry Harrison
# 9            10                   John Tyler
# 10           11                James K. Polk
# 11           12               Zachary Taylor
# 12           13             Millard Fillmore
# 13           14              Franklin Pierce
# 14           15               James Buchanan
# 15           16              Abraham Lincoln
# 16           17               Andrew Johnson
# 17           18             Ulysses S. Grant
# 18           19          Rutherford B. Hayes
# 19           20            James A. Garfield
# ...

# %%
# df.rename(mapper=lambda x:x.upper(),axis="columns")
df=df.rename(mapper=lambda x:x.upper(),axis=1,inplace=True)
df

# %%
df

# %%
df=pd.read_csv("presidents.csv")
df.head()
# Out:
#    Presidency          President   \
# 0            1  George Washington
# 1            2         John Adams
# 2            3   Thomas Jefferson
# 3            4      James Madison
# 4            5       James Monroe
#
#                                   Wikipedia Entry Took office  Left office   \
# 0  http://en.wikipedia.org/wiki/George_Washington   30/04/1789    4/03/1797
# 1         http://en.wikipedia.org/wiki/John_Adams    4/03/1797    4/03/1801
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson    4/03/1801    4/03/1809
# 3      http://en.wikipedia.org/wiki/James_Madison    4/03/1809    4/03/1817
# 4       http://en.wikipedia.org/wiki/James_Monroe    4/03/1817    4/03/1825
#
#                    Party               Portrait                  Thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 1             Federalist          JohnAdams.jpg         thmb_JohnAdams.jpg
# ...

# %%
df=df.rename(mapper=str.lower,axis="columns")
df=df.rename(mapper=str.strip,axis="columns")
df
# Out:
#     presidency                    president  \
# 0            1            George Washington
# 1            2                   John Adams
# 2            3             Thomas Jefferson
# 3            4                James Madison
# 4            5                 James Monroe
# 5            6            John Quincy Adams
# 6            7               Andrew Jackson
# 7            8             Martin Van Buren
# 8            9       William Henry Harrison
# 9           10                   John Tyler
# 10          11                James K. Polk
# 11          12               Zachary Taylor
# 12          13             Millard Fillmore
# 13          14              Franklin Pierce
# 14          15               James Buchanan
# 15          16              Abraham Lincoln
# 16          17               Andrew Johnson
# 17          18             Ulysses S. Grant
# 18          19          Rutherford B. Hayes
# 19          20            James A. Garfield
# ...

# %%
df=pd.read_csv("admission.csv",index_col=0)
df
df=df.rename(mapper=str.lower,axis="columns")
df=df.rename(mapper=str.strip,axis="columns")
df
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# ...

# %%
df.reset_index()
# Out:
#      Serial No.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      research  chance of admit
# 0           1             0.92
# ...

# %%
df.setIndex
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-f8a655ecc58e> in <module>
# ----> 1 df.drop('sop')
#
# c:\users\jsgok\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# c:\users\jsgok\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
import pandas as pd
s1 = pd.Series({1: 'Alice', 2: 'Jack', 3: 'Molly'})
s2 = pd.Series({'Alice': 1, 'Jack': 2, 'Molly': 3})

# %%
s1
# Out:
# 1    Alice
# 2     Jack
# 3    Molly
# dtype: object

# %%
df
# Out:
#      Serial No.  gre score  toefl score  university rating  sop  lor  cgpa  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        324          107                  4  4.0  4.5  8.87
# 2             3        316          104                  3  3.0  3.5  8.00
# 3             4        322          110                  3  3.5  2.5  8.67
# 4             5        314          103                  2  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 395         396        324          110                  3  3.5  3.5  9.04
# 396         397        325          107                  3  3.0  3.5  9.11
# 397         398        330          116                  4  5.0  4.5  9.45
# 398         399        312          103                  3  3.5  4.0  8.78
# 399         400        333          117                  4  5.0  4.0  9.66
#
#      research  chance of admit
# 0           1             0.92
# ...

# %%
df=df.set_index('serial NO.')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-649089259610> in <module>
# ----> 1 df=df.set_index('serial NO.')
#
# c:\users\jsgok\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['serial NO.'] are in the columns"

# %%
df=pd.read_csv("presidents.csv")
df.head()
# Out:
#    Presidency          President   \
# 0            1  George Washington
# 1            2         John Adams
# 2            3   Thomas Jefferson
# 3            4      James Madison
# 4            5       James Monroe
#
#                                   Wikipedia Entry Took office  Left office   \
# 0  http://en.wikipedia.org/wiki/George_Washington   30/04/1789    4/03/1797
# 1         http://en.wikipedia.org/wiki/John_Adams    4/03/1797    4/03/1801
# 2   http://en.wikipedia.org/wiki/Thomas_Jefferson    4/03/1801    4/03/1809
# 3      http://en.wikipedia.org/wiki/James_Madison    4/03/1809    4/03/1817
# 4       http://en.wikipedia.org/wiki/James_Monroe    4/03/1817    4/03/1825
#
#                    Party               Portrait                  Thumbnail  \
# 0            Independent   GeorgeWashington.jpg  thmb_GeorgeWashington.jpg
# 1             Federalist          JohnAdams.jpg         thmb_JohnAdams.jpg
# ...

# %%
df=df.set_index("residency")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-c7d087d60b30> in <module>
# ----> 1 df=df.set_index("residency")
#
# c:\users\jsgok\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['residency'] are in the columns"

# %%
df=pd.DataFrame([{
    "Name":"gokul",
    "age":"33"
},
    {
     "name":"cccc",
      "age":"909"
    }
])
df
# Out:
#     Name  age  name
# 0  gokul   33   NaN
# 1    NaN  909  cccc

# %%
df['gokul']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\jsgok\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gokul'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-b9cd2381ff09> in <module>
# ...
