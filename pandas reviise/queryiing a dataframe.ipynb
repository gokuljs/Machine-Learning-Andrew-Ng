# %%
import pandas as pd

# %%
# boolean masking

# %%
df=pd.read_csv("admission.csv",index_col=0)

# %%
print(df)
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 396               324          110                  3  3.5   3.5  9.04
# 397               325          107                  3  3.0   3.5  9.11
# 398               330          116                  4  5.0   4.5  9.45
# 399               312          103                  3  3.5   4.0  8.78
# 400               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
df=df.rename(mapper=str.strip,axis="columns")
df=df.rename(mapper=str.lower,axis="columns")

# %%
df
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# ...

# %%
admit_mask=df['chance of admit']>0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
fail=df.loc[:,'chance of admit']<0.7
fail
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(fail).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 NaN          NaN                NaN  NaN  NaN   NaN
# 2                 NaN          NaN                NaN  NaN  NaN   NaN
# 3                 NaN          NaN                NaN  NaN  NaN   NaN
# 4                 NaN          NaN                NaN  NaN  NaN   NaN
# 5               314.0        103.0                2.0  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                NaN              NaN
# 2                NaN              NaN
# 3                NaN              NaN
# 4                NaN              NaN
# 5                0.0             0.65

# %%
# combining both dropna and where

# %%
df[df['chance of admit']<0.7]
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 5                 314          103                  2  2.0  3.0  8.21
# 8                 308          101                  2  3.0  4.0  7.90
# 9                 302          102                  1  2.0  1.5  8.00
# 10                323          108                  3  3.5  3.0  8.60
# 11                325          106                  3  3.5  4.0  8.40
# ...               ...          ...                ...  ...  ...   ...
# 387               302          101                  2  2.5  3.5  7.96
# 388               307          105                  2  2.0  3.5  8.10
# 389               296           97                  2  1.5  2.0  7.80
# 391               314          102                  2  2.0  2.5  8.24
# 399               312          103                  3  3.5  4.0  8.78
#
#             research  chance of admit
# Serial No.
# 5                  0             0.65
# ...

# %%
df
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# ...

# %%
df.loc[:,['chance of admit']]>0.7
# Out:
#             chance of admit
# Serial No.
# 1                      True
# 2                      True
# 3                      True
# 4                      True
# 5                     False
# ...                     ...
# 396                    True
# 397                    True
# 398                    True
# 399                   False
# 400                    True
#
# [400 rows x 1 columns]

# %%
df[['gre score','toefl score']]
# Out:
#             gre score  toefl score
# Serial No.
# 1                 337          118
# 2                 324          107
# 3                 316          104
# 4                 322          110
# 5                 314          103
# ...               ...          ...
# 396               324          110
# 397               325          107
# 398               330          116
# 399               312          103
# 400               333          117
#
# [400 rows x 2 columns]

# %%
df[df['gre score']>300]
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# ...
