# %%
import pandas as pd

# %%
df=pd.read_csv("admission.csv")

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
len(df)
# Out:
# 400

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
df.T
# Out:
#                       0       1       2       3       4       5       6    \
# Serial No.           1.00    2.00    3.00    4.00    5.00    6.00    7.00
# GRE Score          337.00  324.00  316.00  322.00  314.00  330.00  321.00
# TOEFL Score        118.00  107.00  104.00  110.00  103.00  115.00  109.00
# University Rating    4.00    4.00    3.00    3.00    2.00    5.00    3.00
# SOP                  4.50    4.00    3.00    3.50    2.00    4.50    3.00
# LOR                  4.50    4.50    3.50    2.50    3.00    3.00    4.00
# CGPA                 9.65    8.87    8.00    8.67    8.21    9.34    8.20
# Research             1.00    1.00    1.00    1.00    0.00    1.00    1.00
# Chance of Admit      0.92    0.76    0.72    0.80    0.65    0.90    0.75
#
#                       7      8       9    ...     390     391     392     393  \
# Serial No.           8.00    9.0   10.00  ...  391.00  392.00  393.00  394.00
# ...

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
df.iloc[0]
# Out:
# Serial No.             1.00
# GRE Score            337.00
# TOEFL Score          118.00
# University Rating      4.00
# SOP                    4.50
# LOR                    4.50
# CGPA                   9.65
# Research               1.00
# Chance of Admit        0.92
# Name: 0, dtype: float64

# %%
df.loc[0]
# Out:
# Serial No.             1.00
# GRE Score            337.00
# TOEFL Score          118.00
# University Rating      4.00
# SOP                    4.50
# LOR                    4.50
# CGPA                   9.65
# Research               1.00
# Chance of Admit        0.92
# Name: 0, dtype: float64

# %%
df.loc[:,['Serial No.','GRE Score','TOEFL Score']]
# Out:
#      Serial No.  GRE Score  TOEFL Score
# 0             1        337          118
# 1             2        324          107
# 2             3        316          104
# 3             4        322          110
# 4             5        314          103
# ..          ...        ...          ...
# 395         396        324          110
# 396         397        325          107
# 397         398        330          116
# 398         399        312          103
# 399         400        333          117
#
# [400 rows x 3 columns]

# %%
k=sum(df.loc[:,'GRE Score'])
k
# Out:
# 126723

# %%
s=sum(df.loc[:,'TOEFL Score'])
s
# Out:
# 42964

# %%
k>s
# Out:
# True

# %%
s>k
# Out:
# False

# %%
df.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
# in above put we can see index starts from 0 and serial number starts from 1

# %%
# if we want we can set a indexcolumn to serial number

# %%
df=pd.read_csv("admission.csv",index_col=0)# index_col=which column number you want 
df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
# ...               ...          ...                ...  ...   ...   ...
# 396               324          110                  3  3.5   3.5  9.04
# 397               325          107                  3  3.0   3.5  9.11
# 398               330          116                  4  5.0   4.5  9.45
# 399               312          103                  3  3.5   4.0  8.78
# 400               333          117                  4  5.0   4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# ...

# %%
# now changing the column names and rename functionn in poandas 
# use df.rename which is used to change the rename value

# %%
new_df=df.rename(columns={'GRE Score':'gre score','TOEFL Score':'toefl score','University Rating':'University Rating',
                         'SOP':'statement of purpose','LOR':'letter of recommendation','CGPA':'CGPA','Research':'Research',
                         'Chance of Admit':'Chance of Admit'})
new_df
# Out:
#             gre score  toefl score  University Rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
# ...               ...          ...                ...                   ...
# 396               324          110                  3                   3.5
# 397               325          107                  3                   3.0
# 398               330          116                  4                   5.0
# 399               312          103                  3                   3.5
# 400               333          117                  4                   5.0
#
# ...

# %%
# to get column nanme use 
new_df.columns
# Out:
# Index(['gre score', 'toefl score', 'University Rating', 'statement of purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df
# Out:
#             gre score  toefl score  University Rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
# ...               ...          ...                ...                   ...
# 396               324          110                  3                   3.5
# 397               325          107                  3                   3.0
# 398               330          116                  4                   5.0
# 399               312          103                  3                   3.5
# 400               333          117                  4                   5.0
#
# ...

# %%
new_df.columns# lor did transform beacuse of space
# Out:
# Index(['gre score', 'toefl score', 'University Rating', 'statement of purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df=df.rename(columns={'GRE Score':'gre score','TOEFL Score':'toefl score','University Rating':'University Rating',
                         'SOP':'statement of purpose','LOR ':'letter of recommendation','CGPA':'CGPA','Research':'Research',
                         'Chance of Admit':'Chance of Admit'})
new_df
# Out:
#             gre score  toefl score  University Rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
# ...               ...          ...                ...                   ...
# 396               324          110                  3                   3.5
# 397               325          107                  3                   3.0
# 398               330          116                  4                   5.0
# 399               312          103                  3                   3.5
# 400               333          117                  4                   5.0
#
# ...

# %%
new_df=df.rename(columns={'GRE Score':'gre score','TOEFL Score':'toefl score','University Rating':'University Rating',
                         'SOP':'statement of purpose','LOR ':'letter of recommendation','CGPA':'CGPA','Research':'Research',
                         'Chance of Admit':'Chance of Admit'})
new_df
# Out:
#             gre score  toefl score  University Rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
# ...               ...          ...                ...                   ...
# 396               324          110                  3                   3.5
# 397               325          107                  3                   3.0
# 398               330          116                  4                   5.0
# 399               312          103                  3                   3.5
# 400               333          117                  4                   5.0
#
# ...

# %%
new_df=new_df.rename(columns={'CGPA':'CGPA OUT OF 10'})
new_df
# Out:
#             gre score  toefl score  University Rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
# ...               ...          ...                ...                   ...
# 396               324          110                  3                   3.5
# 397               325          107                  3                   3.0
# 398               330          116                  4                   5.0
# 399               312          103                  3                   3.5
# 400               333          117                  4                   5.0
#
# ...

# %%
# stri[p is used to remove white spaces in python

# %%
new_df=df.rename(mapper=str.strip,axis='columns')

# %%
new_df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# ...

# %%
new_df=df.rename(columns={'GRE Score':'gre score','TOEFL Score':'toefl score','University Rating':'University Rating',
                         'SOP':'statement of purpose','LOR ':'letter of recommendation','CGPA':'CGPA','Research':'Research',
                         'Chance of Admit':'Chance of Admit'})
new_df
# Out:
#             gre score  toefl score  University Rating  statement of purpose  \
# Serial No.
# 1                 337          118                  4                   4.5
# 2                 324          107                  4                   4.0
# 3                 316          104                  3                   3.0
# 4                 322          110                  3                   3.5
# 5                 314          103                  2                   2.0
# ...               ...          ...                ...                   ...
# 396               324          110                  3                   3.5
# 397               325          107                  3                   3.0
# 398               330          116                  4                   5.0
# 399               312          103                  3                   3.5
# 400               333          117                  4                   5.0
#
# ...

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
# converting to only columns to list

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
k=list(df.columns)
k
# Out:
# ['GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR ',
#  'CGPA',
#  'Research',
#  'Chance of Admit ']

# %%
k=[x.strip() for x in k]
k
# Out:
# ['GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR',
#  'CGPA',
#  'Research',
#  'Chance of Admit']

# %%
df.columns=k
df
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# ...

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR', 'CGPA',
#        'Research', 'Chance of Admit'],
#       dtype='object')
