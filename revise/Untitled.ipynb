# %%
# pandas and numpy speciliazation

# %%
x=1
y=1
x+y
# Out:
# 2

# %%
def add(x,y):
    return x+y
add(11,11)
# Out:
# 22

# %%
x=("gokul js","7 th sem","jsfokuyl; a,sma,")
name,class1,email=x

# %% [markdown]
# name

# %%
name
# Out:
# 'gokul js'

# %%
import csv

# %%
import csv
with open('mpg.csv') as csvfile:
    mpg=list(csv.DictReader(csvfile))
mpg[:3]
# Out:
# [{'mpg': '18',
#   'cylinders': '8',
#   'displacement': '307',
#   'horsepower': '130',
#   'weight': '3504',
#   'acceleration': '12',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'chevrolet chevelle malibu'},
#  {'mpg': '15',
#   'cylinders': '8',
#   'displacement': '350',
#   'horsepower': '165',
#   'weight': '3693',
#   'acceleration': '11.5',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'buick skylark 320'},
#  {'mpg': '18',
#   'cylinders': '8',
#   'displacement': '318',
#   'horsepower': '150',
#   'weight': '3436',
#   'acceleration': '11',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'plymouth satellite'}]

# %%
mpg
# Out:
# [{'mpg': '18',
#   'cylinders': '8',
#   'displacement': '307',
#   'horsepower': '130',
#   'weight': '3504',
#   'acceleration': '12',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'chevrolet chevelle malibu'},
#  {'mpg': '15',
#   'cylinders': '8',
#   'displacement': '350',
#   'horsepower': '165',
#   'weight': '3693',
#   'acceleration': '11.5',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'buick skylark 320'},
#  {'mpg': '18',
#   'cylinders': '8',
#   'displacement': '318',
#   'horsepower': '150',
#   'weight': '3436',
#   'acceleration': '11',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'plymouth satellite'},
#  {'mpg': '16',
#   'cylinders': '8',
#   'displacement': '304',
#   'horsepower': '150',
#   'weight': '3433',
#   'acceleration': '12',
#   'model_year': '70',
#   'origin': '1',
#   'name': 'amc rebel sst'},
#  {'mpg': '17',
#   'cylinders': '8',
#   'displacement': '302',
#   'horsepower': '140',
#   'weight': '3449',
# ...

# %%
len(mpg) # this means we have dictionary for all 398 files
# Out:
# 398

# %%
mpg[0]
# Out:
# {'mpg': '18',
#  'cylinders': '8',
#  'displacement': '307',
#  'horsepower': '130',
#  'weight': '3504',
#  'acceleration': '12',
#  'model_year': '70',
#  'origin': '1',
#  'name': 'chevrolet chevelle malibu'}

# %%
mpg[0].keys()
# Out:
# dict_keys(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'name'])

# %%
mpg[0].values()
# Out:
# dict_values(['18', '8', '307', '130', '3504', '12', '70', '1', 'chevrolet chevelle malibu'])

# %%
sum(float(d['mpg']) for d in mpg)
# Out:
# 9358.800000000003

# %%
#  now i want total mnumber of unique number of cylinders in python for 
distict=set(d['cylinders'] for d in mpg)
distict
# Out:
# {'3', '4', '5', '6', '8'}

# %%
import datetime as dt
import time as tm

# %%
time
# Out:
# Wall time: 0 ns

# %%
import datetime as dt
import time as tm

# %%
tm.time()
# Out:
# 1603894523.2286046
